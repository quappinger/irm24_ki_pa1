# %% [markdown]
# # Project Work - IRM24
# ## Jürgen Aumayr & Natalia Trudova

# %% [markdown]
# ### Decision Trees

# %% [markdown]
# ### Imports und Daten laden

# %% [markdown]
# Dieser Block läd die benötigten Bibliotheken und liest die CSV-Dateien ein, wobei auch einige Spalten für späteren Zugriff (z. B. die Passagier‑IDs) gespeichert werden. Die Ausgabe („head“) gibt Ihnen einen ersten Überblick über die Struktur und Inhalte des Trainingsdatensatzes.

# %%
# Imports für Datenmanipulation, Visualisierung und maschinelles Lernen
import numpy as np
import pandas as pd
import re
import xgboost as xgb
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Imports für interaktive Visualisierungen mit Plotly
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go

# Scikit-learn-Funktionalitäten
from sklearn import tree
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from IPython.display import Image as PImage

# Weitere Hilfsbibliotheken
from subprocess import check_call
from PIL import Image, ImageDraw, ImageFont

# Daten einlesen
train = pd.read_csv('data/train.csv')  # Trainingsdaten laden
test = pd.read_csv('data/test.csv')    # Testdaten laden

# Extrahiere einige Spalten aus dem Testdatensatz, ggf. für spätere Vorhersagen
passenger_ids = test['PassengerId']
test_names = test['Name']
test_sex = test['Sex']

# Zeige die ersten drei Zeilen des Trainingsdatensatzes an (Übersicht der Spalten und Datentypen)
train.head(3)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# ...

# %% [markdown]
# ### Data Engineering

# %% [markdown]
# Dieser umfangreiche Block führt mehrere Transformationsschritte durch. Neben der Erzeugung von Merkmalen wie "Has_Cabin", "FamilySize" und "IsAlone" wird auch der Name der Passagiere genutzt, um deren Titel zu extrahieren. Anschließend werden alle kategorischen Variablen (Sex, Embarked, Title) in numerische Werte umgewandelt und die kontinuierlichen Variablen "Fare" und "Age" in diskrete Kategorien eingeteilt. Dieser Block erzeugt keine direkte Ausgabe, bewirkt aber eine umfassende Datenaufbereitung für die weitere Modellierung.

# %%
# Back-up des Originaldatensatzes, um später bei Bedarf auf die unveränderten Daten zurückgreifen zu können
original_train = train.copy()

# Wir kombinieren Trainings- und Testdaten in einer Liste, um konsistente Transformationen durchzuführen
full_data = [train, test]

# Neue binäre Feature "Has_Cabin": 1, falls eine Kabine vorhanden ist, 0 sonst
for dataset in full_data:
    dataset['Has_Cabin'] = dataset['Cabin'].notna().astype(int)

# Erstelle das Feature "FamilySize", welches die vorhandenen Geschwister-/Ehepartner- (SibSp) und Eltern-/Kinderzahlen (Parch) zusammenzählt und 1 hinzufügt (den Passagier selbst)
# Daraus wird das Feature "IsAlone" abgeleitet, das angibt, ob der Passagier allein reist
for dataset in full_data:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1
    dataset['IsAlone'] = (dataset['FamilySize'] == 1).astype(int)

# Fehlende Werte in der "Embarked" Spalte durch den häufigsten Eintrag "S" ersetzen
for dataset in full_data:
    dataset['Embarked'].fillna('S', inplace=True)

# Fehlende Werte in der "Fare" Spalte durch den Medianwert aus dem Trainingsdatensatz ersetzen
for dataset in full_data:
    dataset['Fare'].fillna(train['Fare'].median(), inplace=True)

# Fehlende Alterswerte werden mit zufälligen Werten aus dem Intervall [mean - std, mean + std] ersetzt
for dataset in full_data:
    age_avg = dataset['Age'].mean()
    age_std = dataset['Age'].std()
    age_null_count = dataset['Age'].isnull().sum()
    # Zufallswerte als Ganzzahlen im angegebenen Bereich erzeugen
    age_null_random_list = np.random.randint(int(age_avg - age_std), int(age_avg + age_std), size=age_null_count)
    dataset.loc[dataset['Age'].isnull(), 'Age'] = age_null_random_list
    dataset['Age'] = dataset['Age'].astype(int)

# Funktion zur Extraktion des Titels aus dem Namen eines Passagiers
def get_title(name):
    match = re.search(r' ([A-Za-z]+)\.', name)
    return match.group(1) if match else ""

# Titel extrahieren, seltene Titel gruppieren und gängige Titel vereinheitlichen
for dataset in full_data:
    dataset['Title'] = dataset['Name'].apply(get_title)
    dataset['Title'] = dataset['Title'].replace(
        ['Lady', 'Countess', 'Capt', 'Col', 'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'],
        'Rare'
    )
    dataset['Title'] = dataset['Title'].replace({'Mlle': 'Miss', 'Ms': 'Miss', 'Mme': 'Mrs'})
    
    # Kategorische Features in numerische Werte überführen
    dataset['Sex'] = dataset['Sex'].map({'female': 0, 'male': 1}).astype(int)
    title_mapping = {"Mr": 1, "Master": 2, "Mrs": 3, "Miss": 4, "Rare": 5}
    dataset['Title'] = dataset['Title'].map(title_mapping).fillna(0).astype(int)
    dataset['Embarked'] = dataset['Embarked'].map({'S': 0, 'C': 1, 'Q': 2}).astype(int)
    
    # "Fare" in vier Kategorien einteilen
    dataset.loc[dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare'] = 2
    dataset.loc[dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)
    
    # "Age" in 5 Alterskategorien einteilen
    dataset.loc[dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[dataset['Age'] > 64, 'Age'] = 4
    dataset['Age'] = dataset['Age'].astype(int)

# %% [markdown]
# ### Data Selection

# %% [markdown]
# Nach der umfangreichen Feature Engineering Phase werden hier Spalten entfernt, die für den Entscheidungsbaum nicht benötigt werden. Dadurch wird der Datensatz kompakter und die Modellierung kann sich auf die aussagekräftigen Merkmale konzentrieren.

# %%
# Entferne Variablen, die für die Modellierung als nicht relevant erachtet werden.
# Dazu gehören u. a. Identifikationsnummern und Textinformationen, welche bereits in andere Merkmale transformiert wurden.
columns_to_drop = ['PassengerId', 'Name', 'Ticket', 'Cabin', 'SibSp']
train.drop(columns=columns_to_drop, inplace=True)
test.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# ### Überblick über den verarbeiteten Datensatz

# %% [markdown]
# Dieser Block gibt die ersten drei Zeilen des Trainingsdatensatzes aus – nun mit allen neu generierten und umkodierten Daten. So kann schnell kontrolliert werden, ob die Transformationen wie erwartet durchgeführt wurden.

# %%
train.head(3)
# Out:
#    Survived  Pclass  Sex  Age  Parch  Fare  Embarked  Has_Cabin  FamilySize  \
# 0         0       3    1    1      0     0         0          0           2
# 1         1       1    0    2      0     3         1          1           2
# 2         1       3    0    1      0     1         0          0           1
#
#    IsAlone  Title
# 0        0      1
# 1        0      3
# 2        1      4

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(train.astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %%
train[['Title', 'Survived']].groupby(['Title'], as_index=False).agg(['mean', 'count', 'sum'])
# Since "Survived" is a binary class (0 or 1), these metrics grouped by the Title feature represent:
    # MEAN: survival rate
    # COUNT: total observations
    # SUM: people survived

# title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
# Out:
#        Survived
#            mean count  sum
# Title
# 1      0.156673   517   81
# 2      0.575000    40   23
# 3      0.793651   126  100
# 4      0.702703   185  130
# 5      0.347826    23    8

# %%
train[['Sex', 'Survived']].groupby(['Sex'], as_index=False).agg(['mean', 'count', 'sum'])
# Since Survived is a binary feature, this metrics grouped by the Sex feature represent:
    # MEAN: survival rate
    # COUNT: total observations
    # SUM: people survived
    
# sex_mapping = {{'female': 0, 'male': 1}}
# Out:
#      Survived
#          mean count  sum
# Sex
# 0    0.742038   314  233
# 1    0.188908   577  109

# %%
# Let's use our 'original_train' dataframe to check the sex distribution for each title.
# We use copy() again to prevent modifications in out original_train dataset
title_and_sex = original_train.copy()[['Name', 'Sex']]

# Create 'Title' feature
title_and_sex['Title'] = title_and_sex['Name'].apply(get_title)

# Map 'Sex' as binary feature
title_and_sex['Sex'] = title_and_sex['Sex'].map( {'female': 0, 'male': 1} ).astype(int)

# Table with 'Sex' distribution grouped by 'Title'
title_and_sex[['Title', 'Sex']].groupby(['Title'], as_index=False).agg(['mean', 'count', 'sum'])

# Since Sex is a binary feature, this metrics grouped by the Title feature represent:
    # MEAN: percentage of men
    # COUNT: total observations
    # SUM: number of men
# Out:
#                Sex
#               mean count  sum
# Title
# Capt      1.000000     1    1
# Col       1.000000     2    2
# Countess  0.000000     1    0
# Don       1.000000     1    1
# Dr        0.857143     7    6
# Jonkheer  1.000000     1    1
# Lady      0.000000     1    0
# Major     1.000000     2    2
# Master    1.000000    40   40
# Miss      0.000000   182    0
# Mlle      0.000000     2    0
# Mme       0.000000     1    0
# Mr        1.000000   517  517
# Mrs       0.000000   125    0
# Ms        0.000000     1    0
# Rev       1.000000     6    6
# Sir       1.000000     1    1

# %%
# Define function to calculate Gini Impurity
def get_gini_impurity(survived_count, total_count):
    survival_prob = survived_count/total_count
    not_survival_prob = (1 - survival_prob)
    random_observation_survived_prob = survival_prob
    random_observation_not_survived_prob = (1 - random_observation_survived_prob)
    mislabelling_survided_prob = not_survival_prob * random_observation_survived_prob
    mislabelling_not_survided_prob = survival_prob * random_observation_not_survived_prob
    gini_impurity = mislabelling_survided_prob + mislabelling_not_survided_prob
    return gini_impurity

# %%
# Gini Impurity of starting node
gini_impurity_starting_node = get_gini_impurity(342, 891)
gini_impurity_starting_node
# Out:
# 0.47301295786144265

# %%
# Gini Impurity decrease of node for 'male' observations
gini_impurity_men = get_gini_impurity(109, 577)
gini_impurity_men
# Out:
# 0.3064437162277843

# %%
# Gini Impurity decrease if node splited for 'female' observations
gini_impurity_women = get_gini_impurity(233, 314)
gini_impurity_women
# Out:
# 0.3828350034484158

# %%
# Gini Impurity decrease if node splited by Sex
men_weight = 577/891
women_weight = 314/891
weighted_gini_impurity_sex_split = (gini_impurity_men * men_weight) + (gini_impurity_women * women_weight)

sex_gini_decrease = weighted_gini_impurity_sex_split - gini_impurity_starting_node
sex_gini_decrease
# Out:
# -0.13964795747285214

# %%
# Gini Impurity decrease of node for observations with Title == 1 == Mr
gini_impurity_title_1 = get_gini_impurity(81, 517)
gini_impurity_title_1
# Out:
# 0.26425329886377663

# %%
# Gini Impurity decrease if node splited for observations with Title != 1 != Mr
gini_impurity_title_others = get_gini_impurity(261, 374)
gini_impurity_title_others
# Out:
# 0.42170207898424317

# %%
# Gini Impurity decrease if node splited for observations with Title == 1 == Mr
title_1_weight = 517/891
title_others_weight = 374/891
weighted_gini_impurity_title_split = (gini_impurity_title_1 * title_1_weight) + (gini_impurity_title_others * title_others_weight)

title_gini_decrease = weighted_gini_impurity_title_split - gini_impurity_starting_node
title_gini_decrease
# Out:
# -0.14267004758907514

# %%
cv = KFold(n_splits=10)            # Desired number of Cross Validation folds
accuracies = list()
max_attributes = len(list(test))
depth_range = range(1, max_attributes + 1)

# Testing max_depths from 1 to max attributes
# Uncomment prints for details about each Cross Validation pass
for depth in depth_range:
    fold_accuracy = []
    tree_model = tree.DecisionTreeClassifier(max_depth = depth)
    # print("Current max depth: ", depth, "\n")
    for train_fold, valid_fold in cv.split(train):
        f_train = train.loc[train_fold] # Extract train data with cv indices
        f_valid = train.loc[valid_fold] # Extract valid data with cv indices

        model = tree_model.fit(X = f_train.drop(['Survived'], axis=1), 
                               y = f_train["Survived"]) # We fit the model with the fold train data
        valid_acc = model.score(X = f_valid.drop(['Survived'], axis=1), 
                                y = f_valid["Survived"])# We calculate accuracy with the fold validation data
        fold_accuracy.append(valid_acc)

    avg = sum(fold_accuracy)/len(fold_accuracy)
    accuracies.append(avg)
    # print("Accuracy per fold: ", fold_accuracy, "\n")
    # print("Average accuracy: ", avg)
    # print("\n")
    
# Just to show results conveniently
df = pd.DataFrame({"Max Depth": depth_range, "Average Accuracy": accuracies})
df = df[["Max Depth", "Average Accuracy"]]
print(df.to_string(index=False))
# Out:
#  Max Depth  Average Accuracy
#          1          0.782285
#          2          0.799189
#          3          0.828277
#          4          0.819288
#          5          0.821548
#          6          0.804769
#          7          0.798015
#          8          0.804744
#          9          0.805893
#         10          0.810387

# %%
# Create Numpy arrays of train, test and target (Survived) dataframes to feed into our models
y_train = train['Survived']
x_train = train.drop(['Survived'], axis=1).values 
x_test = test.values

# Split dataset into training set and test set to calculate the metrics
x_train1, x_test1, y_train1, y_test1 = train_test_split(x_train, y_train, test_size=0.3, random_state=1) # 70% training and 30% test

# Create Decision Tree with max_depth = 3
decision_tree = tree.DecisionTreeClassifier(max_depth = 3)
decision_tree.fit(x_train, y_train)

# Predicting results for test dataset
y_pred = decision_tree.predict(x_test)
submission = pd.DataFrame({
        "PassengerId": PassengerId,
        "Name": Pname,
        "Sex": Sex,
        "Survive prediction": y_pred
    })
submission.to_csv('submission.csv', index=False)

# Export our trained model as a .dot file
with open("tree1.dot", 'w') as f:
     f = tree.export_graphviz(decision_tree,
                              out_file=f,
                              max_depth = 3,
                              impurity = True,
                              feature_names = list(train.drop(['Survived'], axis=1)),
                              class_names = ['Died', 'Survived'],
                              rounded = True,
                              filled= True )

#Convert .dot to .png to allow display in web notebook
check_call(['dot','-Tpng','tree1.dot','-o','tree1.png'])

# Annotating chart with PIL
img = Image.open("tree1.png")
draw = ImageDraw.Draw(img)
font = ImageFont.truetype('C:\\WINDOWS\\Fonts\\arial.ttf', 26)
draw.text((10, 0), # Drawing offset (position)
         '"Title <= 1.5" corresponds to "Mr." title', # Text to draw
        (0,0,255), # RGB desired color
       font=font) # ImageFont object with desired font
img.save('sample-out.png')
PImage("sample-out.png")

# Code to check available fonts and respective paths
#import matplotlib.font_manager
#matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')

# %%
# Evaluate decision tree
y_pred = decision_tree.predict(x_test1)
accuracy_dt = accuracy_score(y_test1, y_pred)
precision_dt = precision_score(y_test1, y_pred, average='weighted')
recall_dt = recall_score(y_test1, y_pred, average='weighted')
f1_dt = f1_score(y_test1, y_pred, average='weighted')

print("Decision Tree:")
print("---------------------------------------")
print("Accuracy:  " + str(accuracy_dt))
print("Precision: " + str(precision_dt))
print("Recall:    " + str(recall_dt))
print("F1-Score:  " + str(f1_dt) + "\n\n")
# Out:
# Decision Tree:
# ---------------------------------------
# Accuracy:  0.7910447761194029
# Precision: 0.7911314949530525
# Recall:    0.7910447761194029
# F1-Score:  0.7888439745715865
